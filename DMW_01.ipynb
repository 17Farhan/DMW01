# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#read data from dataset into dataframe
df=pd.read_csv('ds_salaries.csv')

# %%
#display first 4 rows
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
#get information about dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
# 1 .Data Reduction
#Remove/reduce unnecessary attribute from dataframe
subset = df[['company_location','company_size','work_year','employment_type','job_title','salary']]
subset.head()
# Out:
#   company_location company_size  work_year employment_type  \
# 0               DE            L       2020              FT
# 1               JP            S       2020              FT
# 2               GB            M       2020              FT
# 3               HN            S       2020              FT
# 4               US            L       2020              FT
#
#                     job_title  salary
# 0              Data Scientist   70000
# 1  Machine Learning Scientist  260000
# 2           Big Data Engineer   85000
# 3        Product Data Analyst   20000
# 4   Machine Learning Engineer  150000

# %%
# 2.Data Cleaning
#find missing values
subset.isnull().sum()
# Out:
# company_location    0
# company_size        0
# work_year           0
# employment_type     0
# job_title           0
# salary              0
# dtype: int64

# %%
#define function for median
def impute_median(series):
   return series.filla(series.median())

# %%
subset2=df[['company_location','company_size','work_year','employment_type','job_title','salary','experience_level']]
subset.head()
# Out:
#   company_location company_size  work_year employment_type  \
# 0               DE            L       2020              FT
# 1               JP            S       2020              FT
# 2               GB            M       2020              FT
# 3               HN            S       2020              FT
# 4               US            L       2020              FT
#
#                     job_title  salary
# 0              Data Scientist   70000
# 1  Machine Learning Scientist  260000
# 2           Big Data Engineer   85000
# 3        Product Data Analyst   20000
# 4   Machine Learning Engineer  150000

# %%
# 3.Data integeation
subset3=pd.merge(subset,subset2,on='company_location')
subset3.head()
# Out:
#   company_location company_size_x  work_year_x employment_type_x  \
# 0               DE              L         2020                FT
# 1               DE              L         2020                FT
# 2               DE              L         2020                FT
# 3               DE              L         2020                FT
# 4               DE              L         2020                FT
#
#       job_title_x  salary_x company_size_y  work_year_y employment_type_y  \
# 0  Data Scientist     70000              L         2020                FT
# 1  Data Scientist     70000              S         2020                FT
# 2  Data Scientist     70000              S         2020                PT
# 3  Data Scientist     70000              L         2020                FT
# 4  Data Scientist     70000              M         2020                FT
#
#                 job_title_y  salary_y experience_level
# 0            Data Scientist     70000               MI
# ...

# %%
# 4.Data Transformation
subset.to_excel('ds_salaries.xlsx')
